# %% [markdown]
# <a href="https://colab.research.google.com/github/dalbertox/js-veanog/blob/main/Colab_Trabajo_Practico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nombre: Alberto Díaz Bautista

# %%
#Importamos modulos
import pandas as pd
import io
import requests
import seaborn as sns
import timeit
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
meteo = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/meteo_fotov.csv')

# %%
meteo
# Out:
#        Unnamed: 0  YEAR  MO  DY  HR  ALLSKY_SFC_SW_DWN  ALLSKY_KT   T2M  \
# 0               0  2017   1   1   0                0.0        0.0 -1.14
# 1               1  2017   1   1   1                0.0        0.0 -0.88
# 2               2  2017   1   1   2                0.0        0.0 -0.70
# 3               3  2017   1   1   3                0.0        0.0 -0.60
# 4               4  2017   1   1   4                0.0        0.0 -0.85
# ...           ...   ...  ..  ..  ..                ...        ...   ...
# 43819       43819  2021  12  31  19                0.0        0.0  9.89
# 43820       43820  2021  12  31  20                0.0        0.0  9.37
# 43821       43821  2021  12  31  21                0.0        0.0  8.73
# 43822       43822  2021  12  31  22                0.0        0.0  8.04
# 43823       43823  2021  12  31  23                0.0        0.0  7.45
#
#        PRECTOTCORR  factor_temp  eficiencia  POT_SUMINISTRADA TIPO_DIA
# ...

# %%
meteo.info()

# %%
#BoxPlot de la Potencia por tipo de día
with sns.axes_style(style='ticks'):
  ax = sns.catplot("TIPO_DIA","POT_SUMINISTRADA",data=meteo, kind="box")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
